# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.formula.api as sm
import pandas as pd

data = pd.read_csv("hn_stories.csv")
ols_val = sm.ols(formula="rank ~ points", data = data).fit()
predicted_vals = ols_val.predict()
plt.scatter(data['points'], data['rank'], marker='o', color='blue')
plt.plot(data['points'], predicted_vals, color='red')
plt.ylabel("Points")
plt.xlabel("Rank")
plt.title("Hacker News Stories: Points vs Rank")
plt.show()

# %%
ols_val.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   rank   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.050
# Date:                Thu, 04 Jun 2026   Prob (F-statistic):              0.307
# Time:                        12:37:48   Log-Likelihood:                -777.53
# No. Observations:                 150   AIC:                             1559.
# Df Residuals:                     148   BIC:                             1565.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     73.1775      4.209     17.387      0.000      64.860      81.495
# ...

# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.formula.api as sm
import pandas as pd

data = pd.read_csv("hn_stories.csv")
ols_val = sm.ols(formula="rank ~ age_hours", data = data).fit()
predicted_vals = ols_val.predict()
plt.scatter(data['age_hours'], data['rank'], marker='o', color='blue')
plt.plot(data['age_hours'], predicted_vals, color='red')
plt.ylabel("Age (Hours)")
plt.xlabel("Rank")
plt.title("Hacker News Stories: Age vs Rank")
plt.show()

# %%
ols_val.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   rank   R-squared:                       0.355
# Model:                            OLS   Adj. R-squared:                  0.351
# Method:                 Least Squares   F-statistic:                     81.51
# Date:                Thu, 04 Jun 2026   Prob (F-statistic):           8.61e-16
# Time:                        12:37:48   Log-Likelihood:                -745.16
# No. Observations:                 150   AIC:                             1494.
# Df Residuals:                     148   BIC:                             1500.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     43.7653      4.530      9.661      0.000      34.813      52.718
# ...

# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.formula.api as sm
import pandas as pd

data = pd.read_csv("hn_stories.csv")
ols_val = sm.ols(formula="rank ~ title_length", data = data).fit()
predicted_vals = ols_val.predict()
plt.scatter(data['title_length'], data['rank'], marker='o', color='blue')
plt.plot(data['title_length'], predicted_vals, color='red')
plt.ylabel("Rank")
plt.xlabel("Title Length")
plt.title("Hacker News Stories: Title Length vs Rank")
plt.show()

# %%
ols_val.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   rank   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                   0.02947
# Date:                Thu, 04 Jun 2026   Prob (F-statistic):              0.864
# Time:                        12:37:48   Log-Likelihood:                -778.05
# No. Observations:                 150   AIC:                             1560.
# Df Residuals:                     148   BIC:                             1566.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# Graph 1 shows how the predicted rank should look when we look at each post's points as our reference data for what will land on the front page. It is very scattered and shows no real meaningful trend. Graph 2 is also very messy but we can see an upward trend on our predicted rank based on our post's age in hours. Lastly, Graph 3 shows no correlation since it is nearly a straight line with no real trend. The most useful data based on our graph is our age in hours since it shows mildly predictable trend.
#
# There is a somewhat linear relationship between rank and age in hours as we can see from the R-Squared value being 0.355, which shows there is something there but it is much worse than the average. There is also an almost negligible linear relationship between the post's rank and its points with an R-Squared value of 0.007 which is practically nothing. And for the relationship between rank and title length, the R-Squared value is zero, so there is genuinely nothing of use for prediction.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score, balanced_accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, average_precision_score, confusion_matrix,
    classification_report, precision_recall_curve, roc_curve
)
from sklearn.calibration import calibration_curve

RANDOM_STATE = 42

front_page_posts = []
for i in range(data['rank'].size):
    if data['source_page'][i] == 1:
        front_page_posts.append(1)
    else:
        front_page_posts.append(0)

feature_names = ["age_hours", "comments"]
print(f"Feature names: {feature_names}")
print("sample feature values:")

X = pd.DataFrame(data[['age_hours', 'comments']], columns=feature_names)
# add front page labels to our dataframe

y = pd.Series(front_page_posts, name='front_page')

print(X.head())
print(y.head())

print(X.tail())
print(y.tail())
# Out:
# Feature names: ['age_hours', 'comments']
# sample feature values:
#    age_hours  comments
# 0   2.000000       532
# 1   0.533333        10
# 2   0.883333         6
# 3   6.000000        69
# 4   6.000000        68
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: front_page, dtype: int64
#      age_hours  comments
# 145       24.0        42
# 146       24.0        60
# 147        8.0        81
# 148       48.0       233
# 149       48.0        78
# 145    0
# 146    0
# 147    0
# 148    0
# 149    0
# Name: front_page, dtype: int64

# %%
print(y.value_counts(normalize=True).rename('class_share'))

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, stratify=y, random_state=RANDOM_STATE
)

print('Train class rate:', y_train.mean().round(3))
print('Test class rate: ', y_test.mean().round(3))
# Out:
# front_page
# 0    0.8
# 1    0.2
# Name: class_share, dtype: float64
# Train class rate: 0.2
# Test class rate:  0.2

# %%
baseline_model = Pipeline([
    ('scaler', StandardScaler()),
    ('model', LogisticRegression(max_iter=1000, random_state=RANDOM_STATE))
])

weighted_model = Pipeline([
    ('scaler', StandardScaler()),
    ('model', LogisticRegression(
        max_iter=1000,
        class_weight='balanced',
        random_state=RANDOM_STATE
    ))
])

baseline_model.fit(X_train, y_train)
weighted_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model',
#                  LogisticRegression(class_weight='balanced', max_iter=1000,
#                                     random_state=42))])

# %%
def evaluate_model(name, model, X_eval, y_eval, threshold=0.50):
    prob = model.predict_proba(X_eval)[:, 1]
    pred = (prob >= threshold).astype(int)
    return {
        'model': name,
        'threshold': threshold,
        'accuracy': accuracy_score(y_eval, pred),
        'balanced_accuracy': balanced_accuracy_score(y_eval, pred),
        'precision': precision_score(y_eval, pred, zero_division=0),
        'recall': recall_score(y_eval, pred, zero_division=0),
        'f1': f1_score(y_eval, pred, zero_division=0),
        'roc_auc': roc_auc_score(y_eval, prob),
        'average_precision': average_precision_score(y_eval, prob),
    }

results = pd.DataFrame([
    evaluate_model('baseline', baseline_model, X_test, y_test),
    evaluate_model('class_weight_balanced', weighted_model, X_test, y_test),
])
results.round(3)
# Out:
#                    model  threshold  accuracy  balanced_accuracy  precision  \
# 0               baseline        0.5     0.800              0.500       0.00
# 1  class_weight_balanced        0.5     0.756              0.847       0.45
#
#    recall     f1  roc_auc  average_precision
# 0     0.0  0.000    0.910              0.748
# 1     1.0  0.621    0.932              0.781

# %%
for name, model in [('baseline', baseline_model), ('class_weight_balanced', weighted_model)]:
    prob = model.predict_proba(X_test)[:, 1]
    pred = (prob >= 0.50).astype(int)
    print(f'\n{name}')
    print(confusion_matrix(y_test, pred))
    print(classification_report(y_test, pred, digits=3, zero_division=0))
# Out:
# baseline
# [[36  0]
#  [ 9  0]]
#               precision    recall  f1-score   support
#
#            0      0.800     1.000     0.889        36
#            1      0.000     0.000     0.000         9
#
#     accuracy                          0.800        45
#    macro avg      0.400     0.500     0.444        45
# weighted avg      0.640     0.800     0.711        45
#
#
# class_weight_balanced
# [[25 11]
#  [ 0  9]]
#               precision    recall  f1-score   support
#
#            0      1.000     0.694     0.820        36
#            1      0.450     1.000     0.621         9
#
#     accuracy                          0.756        45
#    macro avg      0.725     0.847     0.720        45
# weighted avg      0.890     0.756     0.780        45

# %%
X_train2, X_val, y_train2, y_val = train_test_split(
    X_train, y_train, test_size=0.25, stratify=y_train, random_state=RANDOM_STATE
)

threshold_model = Pipeline([
    ('scaler', StandardScaler()),
    ('model', LogisticRegression(max_iter=1000, class_weight='balanced', random_state=RANDOM_STATE))
])
threshold_model.fit(X_train2, y_train2)

val_prob = threshold_model.predict_proba(X_val)[:, 1]
candidate_thresholds = np.linspace(0.05, 0.95, 181)
threshold_rows = []

for t in candidate_thresholds:
    val_pred = (val_prob >= t).astype(int)
    threshold_rows.append({
        'threshold': t,
        'precision': precision_score(y_val, val_pred, zero_division=0),
        'recall': recall_score(y_val, val_pred, zero_division=0),
        'f1': f1_score(y_val, val_pred, zero_division=0),
    })

threshold_df = pd.DataFrame(threshold_rows)
best_threshold = threshold_df.loc[threshold_df['f1'].idxmax(), 'threshold']
print('Best validation threshold by F1:', round(best_threshold, 3))
threshold_df.sort_values('f1', ascending=False).head(10).round(3)
# Out:
# Best validation threshold by F1: 0.73
#      threshold  precision  recall     f1
# 138      0.740      0.429     0.6  0.500
# 137      0.735      0.429     0.6  0.500
# 141      0.755      0.429     0.6  0.500
# 140      0.750      0.429     0.6  0.500
# 139      0.745      0.429     0.6  0.500
# 136      0.730      0.429     0.6  0.500
# 131      0.705      0.375     0.6  0.462
# 132      0.710      0.375     0.6  0.462
# 133      0.715      0.375     0.6  0.462
# 134      0.720      0.375     0.6  0.462

# %%
# Refit on the full training data, then apply the chosen threshold to the untouched test set.
final_model = Pipeline([
    ('scaler', StandardScaler()),
    ('model', LogisticRegression(max_iter=1000, class_weight='balanced', random_state=RANDOM_STATE))
])
final_model.fit(X_train, y_train)

pd.DataFrame([
    evaluate_model('weighted_threshold_0.50', final_model, X_test, y_test, threshold=0.50),
    evaluate_model('weighted_tuned_threshold', final_model, X_test, y_test, threshold=best_threshold),
]).round(3)
# Out:
#                       model  threshold  accuracy  balanced_accuracy  \
# 0   weighted_threshold_0.50       0.50     0.756              0.847
# 1  weighted_tuned_threshold       0.73     0.844              0.778
#
#    precision  recall     f1  roc_auc  average_precision
# 0       0.45   1.000  0.621    0.932              0.781
# 1       0.60   0.667  0.632    0.932              0.781

# %%
plt.figure(figsize=(7, 5))
plt.plot(threshold_df['threshold'], threshold_df['precision'], label='Precision')
plt.plot(threshold_df['threshold'], threshold_df['recall'], label='Recall')
plt.plot(threshold_df['threshold'], threshold_df['f1'], label='F1')
plt.axvline(best_threshold, linestyle='--', label=f'Best threshold = {best_threshold:.2f}')
plt.xlabel('Decision threshold')
plt.ylabel('Metric value')
plt.title('Threshold tuning on validation data')
plt.legend()
plt.show()

# %% [markdown]
# My regressions show me that there are components that go into deciding whether or not something will make the front page that are independent of the metrics displayed on the columns provided to the user data we have scraped, such as a decisive equation or a hidden metric.
